# %% [markdown]
# # Python & Data Science Zero to Hero
# # Assignment - Day 1
# ## Name - R.Hariharan
# ## Email id - rhariharan1701@gmail.com

# %% [markdown]
# # Assignment:
# -  1. Generate random data with NumPy for 1000 data points with 2 columns only.
# -  2. Plot Scatter plot, line plot with that in all variations we covered in the class.
# -  3. Do data analysis on two features of Boston data and write your insights.
# -  4. Apply simple linear regression and submit it as an assignment.

# %% [markdown]
# # 1. Generate random data with NumPy for 1000 data points with 2 columns only.

# %%
import numpy as np

# %%
x1 = np.random.randint(1,1000,size=(10,2))
y1 = np.random.randint(1,1000,size=(10,2))

x2 = np.random.randint(1,1000,size=(10,2))
y2 = np.random.randint(1,1000,size=(10,2))

# %%
dataset = [(x1, y1), 
           (x2, y2)]

# %%
dataset
# Out:
# [(array([[693, 366],
#          [401, 604],
#          [970, 563],
#          [629, 910],
#          [304, 821],
#          [917, 913],
#          [432, 841],
#          [799, 520],
#          [696, 850],
#          [107, 672]]),
#   array([[730, 243],
#          [189, 440],
#          [167, 195],
#          [649, 506],
#          [406, 924],
#          [356, 901],
#          [487,  84],
#          [795, 608],
#          [600, 937],
#          [497, 389]])),
#  (array([[461, 233],
#          [766, 403],
#          [128, 245],
#          [170, 440],
#          [684, 318],
#          [482, 301],
#          [921, 115],
#          [ 73, 303],
#          [951, 103],
#          [694, 478]]),
#   array([[428, 440],
#          [877, 695],
#          [393, 296],
#          [674, 480],
#          [712,  84],
#          [ 67, 760],
#          [995, 237],
#          [393, 495],
#          [512, 966],
#          [381, 924]]))]

# %% [markdown]
# # 2. Plot Scatter plot, line plot with that in all variations we covered in the class.

# %%
import matplotlib.pyplot as plt
import plotly.express as px
import seaborn as sns

# %% [markdown]
# # Scatter Plot

# %%
plt.scatter(dataset[0][0], dataset[0][1], c="orange", s=20, label="From X1, Y1")
plt.scatter(dataset[1][0], dataset[1][1], c="blue", s=10, label="From X2, Y2")
plt.title("Scatter plot between $X$ and $Y$")
plt.xlabel("$X axis$")
plt.ylabel("$Y axis$")
# For enabling the labeling
plt.legend()
plt.show()

# %%
plt.scatter(dataset[0][0], dataset[0][1], c="red", s=60, label="From X1, Y1", marker="*")
plt.scatter(dataset[1][0], dataset[1][1], c="blue", s=30, label="From X2, Y2", marker="^")
plt.title("")
plt.xlabel("$X axis$")
plt.ylabel("$Y axis$")
plt.legend()
plt.show()

# %%
plt.scatter(dataset[0][0], dataset[0][1], c="red", s=100, label="From X1, Y1", marker="o", edgecolors="k")
plt.scatter(dataset[1][0], dataset[1][1], c="green", s=100, label="From X2, Y2", marker="^", edgecolors="y")
plt.title("Labelled data")
plt.xlabel("$X axis$")
plt.ylabel("$Y axis$")
plt.legend()
plt.show()

# %% [markdown]
# # Line Plot

# %%
plt.plot(y1)
plt.title("Line plot")
plt.xlabel("$X$ axis")
plt.ylabel("$Y$ axis")
plt.show()

# %%
plt.plot(x1)
plt.title("Line plot")
plt.xlabel("$X$ axis")
plt.ylabel("$Y$ axis")
plt.show()

# %% [markdown]
# # 3.Do data analysis on two features of Boston data and write your insights and 4. Apply simple linear regression

# %%
import numpy as np
import matplotlib.pyplot as plt 
import pandas as pd  
import seaborn as sns 
# %matplotlib inline
from sklearn.datasets import load_boston
boston_dataset = load_boston()

# %% [markdown]
# ## Linear Regression on Boston Housing Dataset

# %%
boston = pd.DataFrame(boston_dataset.data, columns=boston_dataset.feature_names)
boston.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT
# 0     15.3  396.90   4.98
# 1     17.8  396.90   9.14
# 2     17.8  392.83   4.03
# 3     18.7  394.63   2.94
# 4     18.7  396.90   5.33

# %%
print(boston_dataset.keys())
# Out:
# dict_keys(['data', 'target', 'feature_names', 'DESCR', 'filename'])

# %%
boston['MEDV'] = boston_dataset.target
boston.isnull().sum()
# Out:
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# MEDV       0
# dtype: int64

# %% [markdown]
# # Heatmap

# %%
correlation_matrix = boston.corr().round(2)
sns.heatmap(data=correlation_matrix, annot=True)
plt.show()

# %% [markdown]
# # Using a scatter plot let’s see how these features vary with MEDV.

# %%
plt.figure(figsize=(20, 5))
features = ['LSTAT', 'RM']
target = boston['MEDV']
for i, col in enumerate(features):
    plt.subplot(1, len(features),i+1)
    x = boston[col]
    y = target
    plt.scatter(x, y, marker='o')
    plt.title(col)
    plt.xlabel(col)
    plt.ylabel('MEDV')
